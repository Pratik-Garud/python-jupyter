# %%
import pandas as pd

# %%
import numpy as np

# %%
staff_df = pd.read_csv("Data/staff.csv")
staff_df.head()
# Out:
#        staff_id       staff_name    role    service
# 0  STF-5ca26577     Allison Hill  doctor  emergency
# 1  STF-02ae59ca      Noah Rhodes  doctor  emergency
# 2  STF-d8006e7c  Angie Henderson  doctor  emergency
# 3  STF-212d8b31    Daniel Wagner  doctor  emergency
# 4  STF-107a58e4  Cristian Santos  doctor  emergency

# %%
staff_df["service"].unique()
# Out:
# array(['emergency', 'surgery', 'general_medicine', 'ICU'], dtype=object)

# %%
staff_df["service"] == "surgery"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 105    False
# 106    False
# 107    False
# 108    False
# 109    False
# Name: service, Length: 110, dtype: bool

# %%
staff_df[staff_df["service"] == "surgery"]
# Out:
#         staff_id         staff_name               role  service
# 29  STF-15c07995  Anthony Rodriguez             doctor  surgery
# 30  STF-0aaed714  Rebecca Henderson             doctor  surgery
# 31  STF-30d44186      James Ferrell             doctor  surgery
# 32  STF-46e008d1    Tricia Valencia             doctor  surgery
# 33  STF-f2a7bd6f   Nathan Maldonado              nurse  surgery
# 34  STF-d7c28217     Debra Davidson              nurse  surgery
# 35  STF-2bfe24c1     Jeffrey Chavez              nurse  surgery
# 36  STF-3abc4202       Sherri Baker              nurse  surgery
# 37  STF-bc33b33b   Cassandra Gaines              nurse  surgery
# 38  STF-2c155ebf   Elizabeth Fowler              nurse  surgery
# 39  STF-3007d318    Brittany Farmer              nurse  surgery
# 40  STF-13f243f8       Paula Moreno              nurse  surgery
# 41  STF-7a5180f0         Fred Smith              nurse  surgery
# 42  STF-15269c02      Sherry Decker              nurse  surgery
# ...

# %%
staff_df["service"][staff_df["service"] == "surgery"]
# Out:
# 29    surgery
# 30    surgery
# 31    surgery
# 32    surgery
# 33    surgery
# 34    surgery
# 35    surgery
# 36    surgery
# 37    surgery
# 38    surgery
# 39    surgery
# 40    surgery
# 41    surgery
# 42    surgery
# 43    surgery
# 44    surgery
# 45    surgery
# 46    surgery
# 47    surgery
# 48    surgery
# 49    surgery
# 50    surgery
# Name: service, dtype: object

# %%
staff_df["service"][staff_df["service"] == "surgery"].count()
# Out:
# 22

# %%
(staff_df["service"] == "ICU") & (staff_df["role"] == "doctor")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 105    False
# 106    False
# 107    False
# 108    False
# 109    False
# Length: 110, dtype: bool

# %%
(staff_df["service"] == "ICU") | (staff_df["role"] == "doctor")
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 105    True
# 106    True
# 107    True
# 108    True
# 109    True
# Length: 110, dtype: bool

# %%
(staff_df["service"] == "ICU") and (staff_df["role"] == "doctor")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_33016\2096187337.py in ?()
# ----> 1 (staff_df["service"] == "ICU") and (staff_df["role"] == "doctor")
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1578     @final
#    1579     def __nonzero__(self) -> NoReturn:
# -> 1580         raise ValueError(
#    1581             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1582             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1583         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
np.logical_and(staff_df["service"] == "ICU" , staff_df["role"] == "doctor")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 105    False
# 106    False
# 107    False
# 108    False
# 109    False
# Length: 110, dtype: bool

# %%
staff_df[np.logical_and(staff_df["service"] == "ICU" , staff_df["role"] == "doctor")]
# Out:
#         staff_id     staff_name    role service
# 78  STF-00b6381d  Steve Sanchez  doctor     ICU
# 79  STF-cb0c3c50    Lisa Barnes  doctor     ICU
# 80  STF-dd7b8861  Kelly Donovan  doctor     ICU
# 81  STF-0b0dfb38     Mike Allen  doctor     ICU
# 82  STF-a1659ed6  Michael Evans  doctor     ICU
# 83  STF-ab59db32     Paul Jones  doctor     ICU

# %%
staff_df["role"]["service"][np.logical_and(staff_df["service"] == "ICU" , staff_df["role"] == "doctor")]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 staff_df["role"]["service"][np.logical_and(staff_df["service"] == "ICU" , staff_df["role"] == "doctor")]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
#    1136 # (We will iterate through the generator there to check for slices)
#    1137 if is_iterator(key):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1249, in Series._get_value(self, label, takeable)
#    1246     return self._values[label]
#    1248 # Similar to Index.get_value, but we do not fall back to positional
# -> 1249 loc = self.index.get_loc(label)
#    1251 if is_integer(loc):
# ...

# %%
staff_df.loc[(staff_df["service"] == "ICU") & (staff_df["role"] == "doctor"), ["role", "service"]]
# Out:
#       role service
# 78  doctor     ICU
# 79  doctor     ICU
# 80  doctor     ICU
# 81  doctor     ICU
# 82  doctor     ICU
# 83  doctor     ICU

# %%
staff_df[(staff_df["service"].isin(["ICU","emergency","surgery"])) & ( staff_df["role"] == "doctor")]
# Out:
#         staff_id         staff_name    role    service
# 0   STF-5ca26577       Allison Hill  doctor  emergency
# 1   STF-02ae59ca        Noah Rhodes  doctor  emergency
# 2   STF-d8006e7c    Angie Henderson  doctor  emergency
# 3   STF-212d8b31      Daniel Wagner  doctor  emergency
# 4   STF-107a58e4    Cristian Santos  doctor  emergency
# 29  STF-15c07995  Anthony Rodriguez  doctor    surgery
# 30  STF-0aaed714  Rebecca Henderson  doctor    surgery
# 31  STF-30d44186      James Ferrell  doctor    surgery
# 32  STF-46e008d1    Tricia Valencia  doctor    surgery
# 78  STF-00b6381d      Steve Sanchez  doctor        ICU
# 79  STF-cb0c3c50        Lisa Barnes  doctor        ICU
# 80  STF-dd7b8861      Kelly Donovan  doctor        ICU
# 81  STF-0b0dfb38         Mike Allen  doctor        ICU
# 82  STF-a1659ed6      Michael Evans  doctor        ICU
# 83  STF-ab59db32         Paul Jones  doctor        ICU

# %%
staff_df.loc[(staff_df["service"].isin(["ICU","emergency","surgery"])) & ( staff_df["role"] == "doctor"),["role","service"]]
# Out:
#       role    service
# 0   doctor  emergency
# 1   doctor  emergency
# 2   doctor  emergency
# 3   doctor  emergency
# 4   doctor  emergency
# 29  doctor    surgery
# 30  doctor    surgery
# 31  doctor    surgery
# 32  doctor    surgery
# 78  doctor        ICU
# 79  doctor        ICU
# 80  doctor        ICU
# 81  doctor        ICU
# 82  doctor        ICU
# 83  doctor        ICU

# %%
staff_df[:10]            # select first 10 rows
# Out:
#        staff_id       staff_name    role    service
# 0  STF-5ca26577     Allison Hill  doctor  emergency
# 1  STF-02ae59ca      Noah Rhodes  doctor  emergency
# 2  STF-d8006e7c  Angie Henderson  doctor  emergency
# 3  STF-212d8b31    Daniel Wagner  doctor  emergency
# 4  STF-107a58e4  Cristian Santos  doctor  emergency
# 5  STF-ca932dea  Connie Lawrence   nurse  emergency
# 6  STF-39082289  Abigail Shaffer   nurse  emergency
# 7  STF-702887af       Gina Moore   nurse  emergency
# 8  STF-249f63bb  Gabrielle Davis   nurse  emergency
# 9  STF-094f410b       Ryan Munoz   nurse  emergency

# %%
staff_df[5:10]            # select 5 to 10 rows
# Out:
#        staff_id       staff_name   role    service
# 5  STF-ca932dea  Connie Lawrence  nurse  emergency
# 6  STF-39082289  Abigail Shaffer  nurse  emergency
# 7  STF-702887af       Gina Moore  nurse  emergency
# 8  STF-249f63bb  Gabrielle Davis  nurse  emergency
# 9  STF-094f410b       Ryan Munoz  nurse  emergency

# %%
staff_df.loc[:10]            # select upto and 10 index -> Selecting by index label -> include 10
# Out:
#         staff_id       staff_name    role    service
# 0   STF-5ca26577     Allison Hill  doctor  emergency
# 1   STF-02ae59ca      Noah Rhodes  doctor  emergency
# 2   STF-d8006e7c  Angie Henderson  doctor  emergency
# 3   STF-212d8b31    Daniel Wagner  doctor  emergency
# 4   STF-107a58e4  Cristian Santos  doctor  emergency
# 5   STF-ca932dea  Connie Lawrence   nurse  emergency
# 6   STF-39082289  Abigail Shaffer   nurse  emergency
# 7   STF-702887af       Gina Moore   nurse  emergency
# 8   STF-249f63bb  Gabrielle Davis   nurse  emergency
# 9   STF-094f410b       Ryan Munoz   nurse  emergency
# 10  STF-d7ab0c23   Monica Herrera   nurse  emergency

# %%
staff_df.iloc[:10]            # select first 10 rows -> Selecting by row number -> not include 10
# Out:
#        staff_id       staff_name    role    service
# 0  STF-5ca26577     Allison Hill  doctor  emergency
# 1  STF-02ae59ca      Noah Rhodes  doctor  emergency
# 2  STF-d8006e7c  Angie Henderson  doctor  emergency
# 3  STF-212d8b31    Daniel Wagner  doctor  emergency
# 4  STF-107a58e4  Cristian Santos  doctor  emergency
# 5  STF-ca932dea  Connie Lawrence   nurse  emergency
# 6  STF-39082289  Abigail Shaffer   nurse  emergency
# 7  STF-702887af       Gina Moore   nurse  emergency
# 8  STF-249f63bb  Gabrielle Davis   nurse  emergency
# 9  STF-094f410b       Ryan Munoz   nurse  emergency

# %%
staff_df[ :2][0:10]
# Out:
#        staff_id    staff_name    role    service
# 0  STF-5ca26577  Allison Hill  doctor  emergency
# 1  STF-02ae59ca   Noah Rhodes  doctor  emergency

# %%
staff_df[ 5:10][3:10]  #-> pahale staff_df[5:10] perform hoty nntr tyamedhale [3:10] ghetay
# Out:
#        staff_id       staff_name   role    service
# 8  STF-249f63bb  Gabrielle Davis  nurse  emergency
# 9  STF-094f410b       Ryan Munoz  nurse  emergency

# %%
staff_df[ 5:10]
# Out:
#        staff_id       staff_name   role    service
# 5  STF-ca932dea  Connie Lawrence  nurse  emergency
# 6  STF-39082289  Abigail Shaffer  nurse  emergency
# 7  STF-702887af       Gina Moore  nurse  emergency
# 8  STF-249f63bb  Gabrielle Davis  nurse  emergency
# 9  STF-094f410b       Ryan Munoz  nurse  emergency

# %%
staff_df[ 5:10][3:10]     #Slice twice — second on the first slice
# Out:
#        staff_id       staff_name   role    service
# 8  STF-249f63bb  Gabrielle Davis  nurse  emergency
# 9  STF-094f410b       Ryan Munoz  nurse  emergency

# %%
staff_df.iloc[8:10]           # same as the above
# Out:
#        staff_id       staff_name   role    service
# 8  STF-249f63bb  Gabrielle Davis  nurse  emergency
# 9  STF-094f410b       Ryan Munoz  nurse  emergency

# %%
staff_df[ :2, : 2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (slice(None, 2, None), slice(None, 2, None))
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[69], line 1
# ...

# %%
staff_df.iloc[ :2, : 2]
# Out:
#        staff_id    staff_name
# 0  STF-5ca26577  Allison Hill
# 1  STF-02ae59ca   Noah Rhodes

# %%
staff_df.iloc[ :2, : 3]   # [row,column]  -> [from:upto , from:upto]
# Out:
#        staff_id    staff_name    role
# 0  STF-5ca26577  Allison Hill  doctor
# 1  STF-02ae59ca   Noah Rhodes  doctor

# %%
staff_df.iloc[ :2, : 10]
# Out:
#        staff_id    staff_name    role    service
# 0  STF-5ca26577  Allison Hill  doctor  emergency
# 1  STF-02ae59ca   Noah Rhodes  doctor  emergency

# %%
staff_df.iloc[ :20]   #get first 20 rows
# Out:
#         staff_id        staff_name    role    service
# 0   STF-5ca26577      Allison Hill  doctor  emergency
# 1   STF-02ae59ca       Noah Rhodes  doctor  emergency
# 2   STF-d8006e7c   Angie Henderson  doctor  emergency
# 3   STF-212d8b31     Daniel Wagner  doctor  emergency
# 4   STF-107a58e4   Cristian Santos  doctor  emergency
# 5   STF-ca932dea   Connie Lawrence   nurse  emergency
# 6   STF-39082289   Abigail Shaffer   nurse  emergency
# 7   STF-702887af        Gina Moore   nurse  emergency
# 8   STF-249f63bb   Gabrielle Davis   nurse  emergency
# 9   STF-094f410b        Ryan Munoz   nurse  emergency
# 10  STF-d7ab0c23    Monica Herrera   nurse  emergency
# 11  STF-e51bdcb4      Jamie Arnold   nurse  emergency
# 12  STF-8cabb71f      Lisa Hensley   nurse  emergency
# 13  STF-34c0563d  Michele Williams   nurse  emergency
# 14  STF-130577e6      Dylan Miller   nurse  emergency
# 15  STF-768c9d6f     Brian Ramirez   nurse  emergency
# ...

# %%
staff_df.loc[ :2, ["staff_id","role"]]
# Out:
#        staff_id    role
# 0  STF-5ca26577  doctor
# 1  STF-02ae59ca  doctor
# 2  STF-d8006e7c  doctor

# %%
staff_df
# Out:
#          staff_id       staff_name               role    service
# 0    STF-5ca26577     Allison Hill             doctor  emergency
# 1    STF-02ae59ca      Noah Rhodes             doctor  emergency
# 2    STF-d8006e7c  Angie Henderson             doctor  emergency
# 3    STF-212d8b31    Daniel Wagner             doctor  emergency
# 4    STF-107a58e4  Cristian Santos             doctor  emergency
# ..            ...              ...                ...        ...
# 105  STF-2c8a995d       Marc Moore  nursing_assistant        ICU
# 106  STF-251c7770    Sharon Cherry  nursing_assistant        ICU
# 107  STF-3fb56209   Sierra Johnson  nursing_assistant        ICU
# 108  STF-a8c30e00    Evelyn Galvan  nursing_assistant        ICU
# 109  STF-021fdf9f   Sharon Cochran  nursing_assistant        ICU
#
# [110 rows x 4 columns]

# %%
staff_df.sort_values(by="staff_name",ascending = True)
# Out:
#         staff_id       staff_name               role           service
# 96  STF-1881ede3       Aaron Wise              nurse               ICU
# 6   STF-39082289  Abigail Shaffer              nurse         emergency
# 89  STF-3c9039fc    Aimee Montoya              nurse               ICU
# 0   STF-5ca26577     Allison Hill             doctor         emergency
# 65  STF-48fc5275       Amber Kidd              nurse  general_medicine
# ..           ...              ...                ...               ...
# 60  STF-624c0289  Victoria Garcia              nurse  general_medicine
# 71  STF-613d0d64   Whitney Peters              nurse  general_medicine
# 69  STF-98cc6508    William Baker              nurse  general_medicine
# 84  STF-3bbc468d  Zachary Ferrell              nurse               ICU
# 28  STF-bc4c419e    Zachary Hicks  nursing_assistant         emergency
#
# [110 rows x 4 columns]

# %%
staff_df.sort_values(by=["role","service"],ascending = True)
# Out:
#         staff_id       staff_name               role  service
# 78  STF-00b6381d    Steve Sanchez             doctor      ICU
# 79  STF-cb0c3c50      Lisa Barnes             doctor      ICU
# 80  STF-dd7b8861    Kelly Donovan             doctor      ICU
# 81  STF-0b0dfb38       Mike Allen             doctor      ICU
# 82  STF-a1659ed6    Michael Evans             doctor      ICU
# ..           ...              ...                ...      ...
# 46  STF-00fbd582      John Pierce  nursing_assistant  surgery
# 47  STF-42844552  Shane Henderson  nursing_assistant  surgery
# 48  STF-1ded4330     Joshua Blair  nursing_assistant  surgery
# 49  STF-5d51a8ea      Eric Carney  nursing_assistant  surgery
# 50  STF-b19d1900   Jessica Holmes  nursing_assistant  surgery
#
# [110 rows x 4 columns]

# %%
staff_df.sort_values(by=["role","service"],ascending = [False,True])
# Out:
#          staff_id         staff_name               role           service
# 102  STF-c479af96   Rebecca Valencia  nursing_assistant               ICU
# 103  STF-79236218   Christine Wright  nursing_assistant               ICU
# 104  STF-55d90e65     Richard Henson  nursing_assistant               ICU
# 105  STF-2c8a995d         Marc Moore  nursing_assistant               ICU
# 106  STF-251c7770      Sharon Cherry  nursing_assistant               ICU
# ..            ...                ...                ...               ...
# 53   STF-51ad7d05         Mark Perez             doctor  general_medicine
# 29   STF-15c07995  Anthony Rodriguez             doctor           surgery
# 30   STF-0aaed714  Rebecca Henderson             doctor           surgery
# 31   STF-30d44186      James Ferrell             doctor           surgery
# 32   STF-46e008d1    Tricia Valencia             doctor           surgery
#
# [110 rows x 4 columns]

# %%
staff_df.query("role == 'doctor'")
# Out:
#         staff_id         staff_name    role           service
# 0   STF-5ca26577       Allison Hill  doctor         emergency
# 1   STF-02ae59ca        Noah Rhodes  doctor         emergency
# 2   STF-d8006e7c    Angie Henderson  doctor         emergency
# 3   STF-212d8b31      Daniel Wagner  doctor         emergency
# 4   STF-107a58e4    Cristian Santos  doctor         emergency
# 29  STF-15c07995  Anthony Rodriguez  doctor           surgery
# 30  STF-0aaed714  Rebecca Henderson  doctor           surgery
# 31  STF-30d44186      James Ferrell  doctor           surgery
# 32  STF-46e008d1    Tricia Valencia  doctor           surgery
# 51  STF-b4b308d8       Danny Morgan  doctor  general_medicine
# 52  STF-df08bf0e   Crystal Robinson  doctor  general_medicine
# 53  STF-51ad7d05         Mark Perez  doctor  general_medicine
# 78  STF-00b6381d      Steve Sanchez  doctor               ICU
# 79  STF-cb0c3c50        Lisa Barnes  doctor               ICU
# ...

# %%
staff_df.query("`role` == 'doctor'")
# Out:
#         staff_id         staff_name    role           service
# 0   STF-5ca26577       Allison Hill  doctor         emergency
# 1   STF-02ae59ca        Noah Rhodes  doctor         emergency
# 2   STF-d8006e7c    Angie Henderson  doctor         emergency
# 3   STF-212d8b31      Daniel Wagner  doctor         emergency
# 4   STF-107a58e4    Cristian Santos  doctor         emergency
# 29  STF-15c07995  Anthony Rodriguez  doctor           surgery
# 30  STF-0aaed714  Rebecca Henderson  doctor           surgery
# 31  STF-30d44186      James Ferrell  doctor           surgery
# 32  STF-46e008d1    Tricia Valencia  doctor           surgery
# 51  STF-b4b308d8       Danny Morgan  doctor  general_medicine
# 52  STF-df08bf0e   Crystal Robinson  doctor  general_medicine
# 53  STF-51ad7d05         Mark Perez  doctor  general_medicine
# 78  STF-00b6381d      Steve Sanchez  doctor               ICU
# 79  STF-cb0c3c50        Lisa Barnes  doctor               ICU
# ...

# %%
staff_df.query("'role' == 'doctor'")    # column name under `` this and rows values under ''
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 staff_df.query("'role' == 'doctor'")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4837, in DataFrame.query(self, expr, inplace, **kwargs)
#    4834 res = self.eval(expr, **kwargs)
#    4836 try:
# -> 4837     result = self.loc[res]
#    4838 except ValueError:
#    4839     # when res is multi-dimensional loc raises, but this is sometimes a
#    4840     # valid query
#    4841     result = self[res]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...

# %%
staff_df.query("`role` == `doctor`")    # column name under `` this and rows values under ''
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\scope.py:231, in Scope.resolve(self, key, is_local)
#     230 if self.has_resolvers:
# --> 231     return self.resolvers[key]
#     233 # if we're here that means that we have no locals and we also have
#     234 # no resolvers
#
# File ~\anaconda3\Lib\collections\__init__.py:1015, in ChainMap.__getitem__(self, key)
#    1014         pass
# -> 1015 return self.__missing__(key)
#
# File ~\anaconda3\Lib\collections\__init__.py:1007, in ChainMap.__missing__(self, key)
#    1006 def __missing__(self, key):
# -> 1007     raise KeyError(key)
#
# KeyError: 'doctor'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
staff_df.query("`role` == 'doctor'")          # back tick `` nahi lihili tri chalte connecting name asel tr like count_of_num -> count of num sathi lihav lagel
# Out:
#         staff_id         staff_name    role           service
# 0   STF-5ca26577       Allison Hill  doctor         emergency
# 1   STF-02ae59ca        Noah Rhodes  doctor         emergency
# 2   STF-d8006e7c    Angie Henderson  doctor         emergency
# 3   STF-212d8b31      Daniel Wagner  doctor         emergency
# 4   STF-107a58e4    Cristian Santos  doctor         emergency
# 29  STF-15c07995  Anthony Rodriguez  doctor           surgery
# 30  STF-0aaed714  Rebecca Henderson  doctor           surgery
# 31  STF-30d44186      James Ferrell  doctor           surgery
# 32  STF-46e008d1    Tricia Valencia  doctor           surgery
# 51  STF-b4b308d8       Danny Morgan  doctor  general_medicine
# 52  STF-df08bf0e   Crystal Robinson  doctor  general_medicine
# 53  STF-51ad7d05         Mark Perez  doctor  general_medicine
# 78  STF-00b6381d      Steve Sanchez  doctor               ICU
# 79  STF-cb0c3c50        Lisa Barnes  doctor               ICU
# ...

# %%
staff_df.head(1)
# Out:
#        staff_id    staff_name    role    service
# 0  STF-5ca26577  Allison Hill  doctor  emergency

# %%
staff_df.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x00000197C7CD2350>

# %%
for idx,rows in staff_df.iterrows():
    print(idx,rows)
    break
# Out:
# 0 staff_id      STF-5ca26577
# staff_name    Allison Hill
# role                doctor
# service          emergency
# Name: 0, dtype: object

# %%
count=0
for idx,rows in staff_df.iterrows():
    print(idx,rows)
    count+=1
# Out:
# 0 staff_id      STF-5ca26577
# staff_name    Allison Hill
# role                doctor
# service          emergency
# Name: 0, dtype: object
# 1 staff_id      STF-02ae59ca
# staff_name     Noah Rhodes
# role                doctor
# service          emergency
# Name: 1, dtype: object
# 2 staff_id         STF-d8006e7c
# staff_name    Angie Henderson
# role                   doctor
# service             emergency
# Name: 2, dtype: object
# 3 staff_id       STF-212d8b31
# staff_name    Daniel Wagner
# role                 doctor
# service           emergency
# Name: 3, dtype: object
# 4 staff_id         STF-107a58e4
# staff_name    Cristian Santos
# role                   doctor
# service             emergency
# Name: 4, dtype: object
# 5 staff_id         STF-ca932dea
# staff_name    Connie Lawrence
# role                    nurse
# service             emergency
# Name: 5, dtype: object
# 6 staff_id         STF-39082289
# staff_name    Abigail Shaffer
# role                    nurse
# ...

# %%
print(count)
# Out:
# 110

# %%
staff_df.shape
# Out:
# (110, 4)
